# %% [markdown]
# <h1 style="color:violet;"> Wrestle Android App Store Data into Beautiful Looking Charts with Plotly</h1>

# %% [markdown]
# <p style="color:smokewhite; font-size:20px;">Have you ever thought about building your own an iOS or Android app? If so, then you probably have wondered about how things work in the app stores. Today we'll replicate some of the app store analytics provided by companies like App Annie or Sensor Tower that helps inform development and app marketing strategies for many companies. This stuff is BIG business!</p>

# %% [markdown]
# <h2 style="color:violet"><em>Questions to answer</em></h2>
# <ol style="font-size:20px">
# <li>How competitive different app categories (e.g., Games, Lifestyle, Weather) are</li>
# <li>Which app category offers compelling opportunities based on its popularity</li>
# <li>How many downloads you would give up by making your app paid vs. free</li>
# <li>How much you can reasonably charge for a paid app</li>
# <li>Which paid apps have had the highest revenue</li>
# <li>How many paid apps will recoup their development costs based on their sales revenue</li>
#
# </ol>

# %% [markdown]
# <h3 style="color:violet;"><em>Importing the needed packages</em></h3>

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# <h3 style="color:violet;"><em>Loading the data</em></h3>

# %%
app_df = pd.read_csv("./data/apps.csv")

# %% [markdown]
# <h3 style="color:violet;"><em>Preliminary Explorations</em></h3>

# %%
app_df.head()
# Out:
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres  \
# 0        0       8.7        0  Paid  $13.99           Teen           Social
# 1        0      33.0        0  Paid   $2.99       Everyone        Education
# 2        0       5.5        0  Paid   $1.49       Everyone  Personalization
# 3        0      19.0        0   NaN       0   Everyone 10+         Strategy
# 4        0      10.0        0  Free       0       Everyone         Business
#
#      Last_Updated         Android_Ver
# 0   July 28, 2017          4.1 and up
# 1  April 15, 2016          3.0 and up
# 2   July 11, 2018          4.2 and up
# 3   June 28, 2018  Varies with device
# 4  August 6, 2018          4.1 and up

# %%
app_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size_MBs        10841 non-null  float64
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content_Rating  10841 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last_Updated    10841 non-null  object
#  11  Android_Ver     10839 non-null  object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 1016.5+ KB

# %%
app_df.describe().T
# Out:
#             count           mean           std       min   25%     50%  \
# Rating     9367.0       4.191513  5.157352e-01  1.000000   4.0     4.3
# Reviews   10841.0  444111.928051  2.927629e+06  0.000000  38.0  2094.0
# Size_MBs  10841.0      19.774147  2.140435e+01  0.008301   4.9    11.0
#
#               75%         max
# Rating        4.5         5.0
# Reviews   54768.0  78158306.0
# Size_MBs     27.0       100.0

# %% [markdown]
# <h3 style="color:violet;"><em>Droping Columns that are not needed</em></h3>

# %%
app_df.drop(columns=['Last_Updated', 'Android_Ver'], inplace=True)

# %%
app_df.head()
# Out:
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres
# 0        0       8.7        0  Paid  $13.99           Teen           Social
# 1        0      33.0        0  Paid   $2.99       Everyone        Education
# 2        0       5.5        0  Paid   $1.49       Everyone  Personalization
# 3        0      19.0        0   NaN       0   Everyone 10+         Strategy
# 4        0      10.0        0  Free       0       Everyone         Business

# %% [markdown]
# <h3 style="color:violet;"><em>Checking missing values and Dropping them</em></h3>

# %%
app_df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size_MBs             0
# Installs             0
# Type                 1
# Price                0
# Content_Rating       0
# Genres               0
# dtype: int64

# %%
clean_df = app_df.dropna()

# %%
clean_df.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size_MBs          0
# Installs          0
# Type              0
# Price             0
# Content_Rating    0
# Genres            0
# dtype: int64

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9367 entries, 21 to 10840
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9367 non-null   object
#  1   Category        9367 non-null   object
#  2   Rating          9367 non-null   float64
#  3   Reviews         9367 non-null   int64
#  4   Size_MBs        9367 non-null   float64
#  5   Installs        9367 non-null   object
#  6   Type            9367 non-null   object
#  7   Price           9367 non-null   object
#  8   Content_Rating  9367 non-null   object
#  9   Genres          9367 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 805.0+ KB

# %% [markdown]
# <h3 style="color:violet;"><em>Checking for duplicate and removing them</em></h3>

# %%
clean_df.duplicated().sum()
# Out:
# 476

# %%
clean_df[clean_df.duplicated()].sort_values('App')
# Out:
#                                                      App            Category  \
# 6371                               10 Best Foods for You  HEALTH_AND_FITNESS
# 7159                          1800 Contacts - Lens Store             MEDICAL
# 2604                          2017 EMRA Antibiotic Guide             MEDICAL
# 5140                        21-Day Meditation Experience  HEALTH_AND_FITNESS
# 946                               420 BZ Budeze Delivery             MEDICAL
# ...                                                  ...                 ...
# 9635   theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 9634   theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 9632   theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 10156                           trivago: Hotels & Travel    TRAVEL_AND_LOCAL
# 10159                           trivago: Hotels & Travel    TRAVEL_AND_LOCAL
#
#        Rating  Reviews  Size_MBs    Installs  Type   Price Content_Rating  \
# 6371      4.0     2490       3.8     500,000  Free       0   Everyone 10+
# 7159      4.7    23160      26.0   1,000,000  Free       0       Everyone
# 2604      4.4       12       3.8       1,000  Paid  $16.99       Everyone
# 5140      4.4    11506      15.0     100,000  Free       0       Everyone
# 946       5.0        2      11.0         100  Free       0     Mature 17+
# ...       ...      ...       ...         ...   ...     ...            ...
# 9635      4.4   133833      34.0  10,000,000  Free       0   Everyone 10+
# 9634      4.4   133833      34.0  10,000,000  Free       0   Everyone 10+
# 9632      4.4   133825      34.0  10,000,000  Free       0   Everyone 10+
# 10156     4.2   219848      12.0  50,000,000  Free       0       Everyone
# 10159     4.2   219848      12.0  50,000,000  Free       0       Everyone
#
#                  Genres
# 6371   Health & Fitness
# 7159            Medical
# 2604            Medical
# 5140   Health & Fitness
# 946             Medical
# ...                 ...
# 9635             Sports
# 9634             Sports
# 9632             Sports
# 10156    Travel & Local
# 10159    Travel & Local
#
# [476 rows x 10 columns]

# %%
cleaned_df = clean_df.drop_duplicates(subset=["App", "Type", "Price"])

# %%
cleaned_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <h4 style="color:smokewhite;">Which Apps are the highest rated</h4>

# %%
cleaned_df['Rating'].max()
# Out:
# 5.0

# %%
cleaned_df.loc[cleaned_df['Rating'] == cleaned_df['Rating'].max()]
# Out:
#                                                    App   Category  Rating  \
# 21                                 KBA-EZ Health Guide    MEDICAL     5.0
# 28                                            Ra Ga Ba       GAME     5.0
# 47                                             Mu.F.O.       GAME     5.0
# 82                                    Brick Breaker BR       GAME     5.0
# 99     Anatomy & Physiology Vocabulary Exam Review App    MEDICAL     5.0
# ...                                                ...        ...     ...
# 2680                               Florida Wildflowers     FAMILY     5.0
# 2750  Superheroes, Marvel, DC, Comics, TV, Movies News     COMICS     5.0
# 3030           CL Keyboard - Myanmar Keyboard (No Ads)      TOOLS     5.0
# 3115                                        Oración CX  LIFESTYLE     5.0
# 4058                          Ek Bander Ne Kholi Dukan     FAMILY     5.0
#
#       Reviews  Size_MBs Installs  Type  Price Content_Rating         Genres
# 21          4      25.0        1  Free      0       Everyone        Medical
# 28          2      20.0        1  Paid  $1.49       Everyone         Arcade
# 47          2      16.0        1  Paid  $0.99       Everyone         Arcade
# 82          7      19.0        5  Free      0       Everyone         Arcade
# 99          1       4.6        5  Free      0       Everyone        Medical
# ...       ...       ...      ...   ...    ...            ...            ...
# 2680        5      69.0    1,000  Free      0       Everyone      Education
# 2750       34      12.0    5,000  Free      0       Everyone         Comics
# 3030       24       3.2    5,000  Free      0       Everyone          Tools
# 3115      103       3.8    5,000  Free      0       Everyone      Lifestyle
# 4058       10       3.0   10,000  Free      0       Everyone  Entertainment
#
# [271 rows x 10 columns]

# %%
# Alternatively
cleaned_df.sort_values("Rating", ascending=False).head()
# Out:
#                       App     Category  Rating  Reviews  Size_MBs Installs  \
# 21    KBA-EZ Health Guide      MEDICAL     5.0        4      25.0        1
# 1230         Sway Medical      MEDICAL     5.0        3      22.0      100
# 1227    AJ Men's Grooming    LIFESTYLE     5.0        2      22.0      100
# 1224       FK Dedinje BGD       SPORTS     5.0       36       2.6      100
# 1223      CB VIDEO VISION  PHOTOGRAPHY     5.0       13       2.6      100
#
#       Type Price Content_Rating       Genres
# 21    Free     0       Everyone      Medical
# 1230  Free     0       Everyone      Medical
# 1227  Free     0       Everyone    Lifestyle
# 1224  Free     0       Everyone       Sports
# 1223  Free     0       Everyone  Photography

# %% [markdown]
# <h4 style="color:smokewhite;">Which Apps are the largest in Downloadable size</h4>

# %%
cleaned_df['Size_MBs'].max()
# Out:
# 100.0

# %%
cleaned_df.loc[cleaned_df['Size_MBs'] == cleaned_df['Size_MBs'].max()]
# Out:
#                                                     App            Category  \
# 1795                               Navi Radiography Pro             MEDICAL
# 3144                                         Vi Trainer  HEALTH_AND_FITNESS
# 4176   Car Crash III Beam DH Real Damage Simulator 2018                GAME
# 7926                                          Post Bank             FINANCE
# 7927                        The Walking Dead: Our World                GAME
# 7928                      Stickman Legends: Shadow Wars                GAME
# 8718                  Mini Golf King - Multiplayer Game                GAME
# 8719                         Draft Simulator for FUT 18              SPORTS
# 9942                     Talking Babsy Baby: Baby Games           LIFESTYLE
# 9943                              Miami crime simulator                GAME
# 9944                       Gangster Town: Vice District              FAMILY
# 9945                                    Ultimate Tennis              SPORTS
# 10295                                   SimCity BuildIt              FAMILY
# 10687                            Hungry Shark Evolution                GAME
#
#        Rating  Reviews  Size_MBs     Installs  Type   Price Content_Rating  \
# 1795      4.7       11     100.0          500  Paid  $15.99       Everyone
# 3144      3.6      124     100.0        5,000  Free       0       Everyone
# 4176      3.6      151     100.0       10,000  Free       0       Everyone
# 7926      4.5    60449     100.0    1,000,000  Free       0       Everyone
# 7927      4.0    22435     100.0    1,000,000  Free       0           Teen
# 7928      4.4    38419     100.0    1,000,000  Paid   $0.99   Everyone 10+
# 8718      4.5   531458     100.0    5,000,000  Free       0       Everyone
# 8719      4.6   162933     100.0    5,000,000  Free       0       Everyone
# 9942      4.0   140995     100.0   10,000,000  Free       0       Everyone
# 9943      4.0   254518     100.0   10,000,000  Free       0     Mature 17+
# 9944      4.3    65146     100.0   10,000,000  Free       0     Mature 17+
# 9945      4.3   183004     100.0   10,000,000  Free       0       Everyone
# 10295     4.5  4218587     100.0   50,000,000  Free       0   Everyone 10+
# 10687     4.5  6074334     100.0  100,000,000  Free       0           Teen
#
#                        Genres
# 1795                  Medical
# 3144         Health & Fitness
# 4176                   Racing
# 7926                  Finance
# 7927                   Action
# 7928                   Action
# 8718                   Sports
# 8719                   Sports
# 9942   Lifestyle;Pretend Play
# 9943                   Action
# 9944               Simulation
# 9945                   Sports
# 10295              Simulation
# 10687                  Arcade

# %%
#Alternatively
cleaned_df.sort_values("Size_MBs", ascending=False)
# Out:
#                                   App            Category  Rating  Reviews  \
# 9942   Talking Babsy Baby: Baby Games           LIFESTYLE     4.0   140995
# 10687          Hungry Shark Evolution                GAME     4.5  6074334
# 9943            Miami crime simulator                GAME     4.0   254518
# 9944     Gangster Town: Vice District              FAMILY     4.3    65146
# 3144                       Vi Trainer  HEALTH_AND_FITNESS     3.6      124
# ...                               ...                 ...     ...      ...
# 2648      Ad Remove Plugin for App2SD        PRODUCTIVITY     4.1       66
# 5798                 ExDialer PRO Key       COMMUNICATION     4.5     5474
# 2684     My baby firework (Remove ad)              FAMILY     4.1       30
# 7966             Market Update Helper  LIBRARIES_AND_DEMO     4.1    20145
# 4696              Essential Resources  LIBRARIES_AND_DEMO     4.6      237
#
#          Size_MBs     Installs  Type  Price Content_Rating  \
# 9942   100.000000   10,000,000  Free      0       Everyone
# 10687  100.000000  100,000,000  Free      0           Teen
# 9943   100.000000   10,000,000  Free      0     Mature 17+
# 9944   100.000000   10,000,000  Free      0     Mature 17+
# 3144   100.000000        5,000  Free      0       Everyone
# ...           ...          ...   ...    ...            ...
# 2648     0.016602        1,000  Paid  $1.29       Everyone
# 5798     0.016602      100,000  Paid  $3.99       Everyone
# 2684     0.013672        1,000  Paid  $0.99       Everyone
# 7966     0.010742    1,000,000  Free      0       Everyone
# 4696     0.008301       50,000  Free      0       Everyone
#
#                        Genres
# 9942   Lifestyle;Pretend Play
# 10687                  Arcade
# 9943                   Action
# 9944               Simulation
# 3144         Health & Fitness
# ...                       ...
# 2648             Productivity
# 5798            Communication
# 2684            Entertainment
# 7966         Libraries & Demo
# 4696         Libraries & Demo
#
# [8199 rows x 10 columns]

# %% [markdown]
# <h4 style="color:smokewhite;">Which Apps have the highest number of Reviews</h4>

# %%
cleaned_df['Reviews'].max()
# Out:
# 78158306

# %%
cleaned_df.loc[cleaned_df['Reviews'] == cleaned_df["Reviews"].max()]
# Out:
#             App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10805  Facebook   SOCIAL     4.1  78158306       5.3  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10805     0           Teen  Social

# %%
# Alternatively
cleaned_df.sort_values("Reviews", ascending=False)
# Out:
#                                                   App            Category  \
# 10805                                        Facebook              SOCIAL
# 10785                              WhatsApp Messenger       COMMUNICATION
# 10806                                       Instagram              SOCIAL
# 10784        Messenger – Text and Video Chat for Free       COMMUNICATION
# 10650                                  Clash of Clans                GAME
# ...                                               ...                 ...
# 453                               Wowkwis aq Ka'qaquj              FAMILY
# 462                                            CB Fit  HEALTH_AND_FITNESS
# 901                   ES Billing System (Offline App)        PRODUCTIVITY
# 1416   Ek Kahani Aisi Bhi Season 3 - The Horror Story              FAMILY
# 1100                                     Chenoweth AH             MEDICAL
#
#        Rating   Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 10805     4.1  78158306       5.3  1,000,000,000  Free     0           Teen
# 10785     4.4  69119316       3.5  1,000,000,000  Free     0       Everyone
# 10806     4.5  66577313       5.3  1,000,000,000  Free     0           Teen
# 10784     4.0  56642847       3.5  1,000,000,000  Free     0       Everyone
# 10650     4.6  44891723      98.0    100,000,000  Free     0   Everyone 10+
# ...       ...       ...       ...            ...   ...   ...            ...
# 453       5.0         1      49.0             10  Free     0       Everyone
# 462       5.0         1       7.8             10  Free     0       Everyone
# 901       5.0         1       4.2            100  Free     0       Everyone
# 1416      3.0         1       5.8            100  Free     0           Teen
# 1100      5.0         1      27.0            100  Free     0       Everyone
#
#                     Genres
# 10805               Social
# 10785        Communication
# 10806               Social
# 10784        Communication
# 10650             Strategy
# ...                    ...
# 453    Education;Education
# 462       Health & Fitness
# 901           Productivity
# 1416         Entertainment
# 1100               Medical
#
# [8199 rows x 10 columns]

# %% [markdown]
# <h3 style="color:violet;"><em>Ploting with Plotly</em></h3>

# %%
content_dist = cleaned_df['Content_Rating'].value_counts()
content_dist
# Out:
# Content_Rating
# Everyone           6621
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: count, dtype: int64

# %%
fig = px.pie(labels=content_dist.index, values=content_dist)
fig.show()

# %%
fig = px.pie(labels=content_dist.index, values=content_dist, title="Content Rating", names=content_dist.index)
fig.update_traces(textposition="outside", textinfo="percent+label")
fig.show()

# %%
fig = px.pie(labels=content_dist.index, values=content_dist, title="Content Rating", names=content_dist.index, hole=0.6)
fig.update_traces(textposition="inside", textinfo="percent", textfont_size=15)
fig.show()

# %% [markdown]
# <h4 style="color:smokewhite;">How many Apps have more than 1 Billion Installs</h4>

# %%
cleaned_df['Installs'].dtype
# Out:
# dtype('O')

# %%
cleaned_df['Installs'].unique()
# Out:
# array(['1', '5', '10', '50', '100', '500', '1,000', '5,000', '10,000',
#        '50,000', '100,000', '500,000', '1,000,000', '5,000,000',
#        '10,000,000', '50,000,000', '100,000,000', '500,000,000',
#        '1,000,000,000'], dtype=object)

# %%
clean_df["Installs"] = cleaned_df['Installs'].str.replace(',', '').astype("int")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 cleaned_df.loc[:, "Installs"] = cleaned_df['Installs'].str.replace(',', '').astype("int")
#
# File c:\Users\user\project_directory\pythonProj\Analytics\nevn\Lib\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# File c:\Users\user\project_directory\pythonProj\Analytics\nevn\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File c:\Users\user\project_directory\pythonProj\Analytics\nevn\Lib\site-packages\pandas\core\strings\accessor.py:190, in StringMethods.__init__(self, data)
#     187 def __init__(self, data) -> None:
#     188     from pandas.core.arrays.string_ import StringDtype
# --> 190     self._inferred_dtype = self._validate(data)
#     191     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     192     self._is_string = isinstance(data.dtype, StringDtype)
#
# File c:\Users\user\project_directory\pythonProj\Analytics\nevn\Lib\site-packages\pandas\core\strings\accessor.py:244, in StringMethods._validate(data)
#     241 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     243 if inferred_dtype not in allowed_types:
# --> 244     raise AttributeError("Can only use .str accessor with string values!")
#     245 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
cleaned_df['Installs'].dtype
# Out:
# dtype('int32')

# %%
cleaned_df[["App", "Installs"]].groupby('Installs').count()
# Out:
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          303
# 500          199
# 1000         698
# 5000         425
# 10000        988
# 50000        457
# 100000      1096
# 500000       504
# 1000000     1417
# 5000000      607
# 10000000     933
# 50000000     202
# 100000000    189
# 500000000     24
# 1000000000    20

# %%
cleaned_df["Price"].dtype
# Out:
# dtype('O')

# %%
cleaned_df["Price"].unique()
# Out:
# array(['0', '$1.49', '$0.99', '$14.99', '$2.49', '$3.04', '$3.49',
#        '$2.99', '$4.99', '$29.99', '$19.99', '$1.99', '$1.76', '$8.99',
#        '$1.75', '$12.99', '$7.99', '$3.99', '$3.88', '$4.59', '$9.99',
#        '$14.00', '$4.49', '$6.99', '$399.99', '$5.99', '$39.99', '$3.02',
#        '$6.49', '$17.99', '$2.00', '$15.99', '$10.99', '$1.61', '$4.29',
#        '$15.46', '$7.49', '$5.49', '$1.70', '$379.99', '$79.99', '$2.56',
#        '$8.49', '$1.50', '$4.84', '$19.40', '$33.99', '$3.08', '$16.99',
#        '$37.99', '$10.00', '$1.29', '$4.60', '$1.00', '$24.99', '$2.50',
#        '$3.90', '$2.95', '$1.97', '$3.28', '$299.99', '$389.99', '$1.20',
#        '$400.00', '$2.59', '$18.99', '$1.59', '$11.99', '$4.77', '$9.00',
#        '$3.95', '$13.99', '$2.90'], dtype=object)

# %%
cleaned_df.loc[:, "Price"] = cleaned_df['Price'].str.replace('$', '').astype("float")

# %%
cleaned_df.sort_values("Price", ascending=False).head(20)
# Out:
#                                  App   Category  Rating  Reviews   Size_MBs  \
# 3946        I'm Rich - Trump Edition  LIFESTYLE     3.6      275   7.300000
# 2461              I AM RICH PRO PLUS    FINANCE     4.0       36  41.000000
# 4606               I Am Rich Premium    FINANCE     4.1     1867   4.700000
# 3145              I am rich(premium)    FINANCE     3.5      472   0.942383
# 3554                      💎 I'm rich  LIFESTYLE     3.8      718  26.000000
# 5765                       I am rich  LIFESTYLE     3.8     3547   1.800000
# 1946  I am rich (Most expensive app)    FINANCE     4.1      129   2.700000
# 2775                   I Am Rich Pro     FAMILY     4.4      201   2.700000
# 3221                  I am Rich Plus     FAMILY     4.0      856   8.700000
# 3114                       I am Rich    FINANCE     4.3      180   3.800000
# 1331          most expensive app (H)     FAMILY     4.3        6   1.500000
# 2394                      I am Rich!    FINANCE     3.8       93  22.000000
# 3897                       I Am Rich     FAMILY     3.6      217   4.900000
# 2193             I am extremely Rich  LIFESTYLE     2.9       41   2.900000
# 3856                   I am rich VIP  LIFESTYLE     3.8      411   2.600000
# 2281       Vargo Anesthesia Mega App    MEDICAL     4.6       92  32.000000
# 1407                    LTC AS Legal    MEDICAL     4.0        6   1.300000
# 2629                I am Rich Person  LIFESTYLE     4.2      134   1.800000
# 2481         A Manual of Acupuncture    MEDICAL     3.5      214  68.000000
# 4264         Golfshot Plus: Golf GPS     SPORTS     4.1     3387  25.000000
#
#       Installs  Type   Price Content_Rating         Genres
# 3946     10000  Paid   400.0       Everyone      Lifestyle
# 2461      1000  Paid  399.99       Everyone        Finance
# 4606     50000  Paid  399.99       Everyone        Finance
# 3145      5000  Paid  399.99       Everyone        Finance
# 3554     10000  Paid  399.99       Everyone      Lifestyle
# 5765    100000  Paid  399.99       Everyone      Lifestyle
# 1946      1000  Paid  399.99           Teen        Finance
# 2775      5000  Paid  399.99       Everyone  Entertainment
# 3221     10000  Paid  399.99       Everyone  Entertainment
# 3114      5000  Paid  399.99       Everyone        Finance
# 1331       100  Paid  399.99       Everyone  Entertainment
# 2394      1000  Paid  399.99       Everyone        Finance
# 3897     10000  Paid  389.99       Everyone  Entertainment
# 2193      1000  Paid  379.99       Everyone      Lifestyle
# 3856     10000  Paid  299.99       Everyone      Lifestyle
# 2281      1000  Paid   79.99       Everyone        Medical
# 1407       100  Paid   39.99       Everyone        Medical
# 2629      1000  Paid   37.99       Everyone      Lifestyle
# 2481      1000  Paid   33.99       Everyone        Medical
# 4264     50000  Paid   29.99       Everyone         Sports

# %%
apps_below_250 = cleaned_df.loc[cleaned_df['Price']<=250]

# %%
apps_below_250["Revenue_Estimate"] =apps_below_250['Installs'] * apps_below_250["Price"]
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7660\3574976083.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
apps_below_250
# Out:
#                                                    App            Category  \
# 21                                 KBA-EZ Health Guide             MEDICAL
# 28                                            Ra Ga Ba                GAME
# 47                                             Mu.F.O.                GAME
# 82                                    Brick Breaker BR                GAME
# 99     Anatomy & Physiology Vocabulary Exam Review App             MEDICAL
# ...                                                ...                 ...
# 10824                                     Google Drive        PRODUCTIVITY
# 10828                                          YouTube       VIDEO_PLAYERS
# 10829                          Google Play Movies & TV       VIDEO_PLAYERS
# 10831                                      Google News  NEWS_AND_MAGAZINES
# 10835                                   Subway Surfers                GAME
#
#        Rating   Reviews  Size_MBs    Installs  Type Price Content_Rating  \
# 21        5.0         4     25.00           1  Free   0.0       Everyone
# 28        5.0         2     20.00           1  Paid  1.49       Everyone
# 47        5.0         2     16.00           1  Paid  0.99       Everyone
# 82        5.0         7     19.00           5  Free   0.0       Everyone
# 99        5.0         1      4.60           5  Free   0.0       Everyone
# ...       ...       ...       ...         ...   ...   ...            ...
# 10824     4.4   2731171      4.00  1000000000  Free   0.0       Everyone
# 10828     4.3  25655305      4.65  1000000000  Free   0.0           Teen
# 10829     3.7    906384      4.65  1000000000  Free   0.0           Teen
# 10831     3.9    877635     13.00  1000000000  Free   0.0           Teen
# 10835     4.5  27722264     76.00  1000000000  Free   0.0   Everyone 10+
#
#                         Genres Revenue_Estimate
# 21                     Medical              0.0
# 28                      Arcade             1.49
# 47                      Arcade             0.99
# 82                      Arcade              0.0
# 99                     Medical              0.0
# ...                        ...              ...
# 10824             Productivity              0.0
# 10828  Video Players & Editors              0.0
# 10829  Video Players & Editors              0.0
# 10831         News & Magazines              0.0
# 10835                   Arcade              0.0
#
# [8184 rows x 11 columns]

# %% [markdown]
# <h4 style="color:smokewhite;">What are the top 10 Highest Gross-paid Apps</h4>

# %%
top_10 = apps_below_250.loc[apps_below_250['Type']=="Paid"].sort_values("Revenue_Estimate", ascending=False).head(10)
top_10
# Out:
#                                 App     Category  Rating  Reviews   Size_MBs  \
# 9220                      Minecraft       FAMILY     4.5  2376564  19.000000
# 8825                  Hitman Sniper         GAME     4.6   408292  29.000000
# 7151  Grand Theft Auto: San Andreas         GAME     4.4   348962  26.000000
# 7477            Facetune - For Free  PHOTOGRAPHY     4.4    49553  48.000000
# 7977        Sleep as Android Unlock    LIFESTYLE     4.5    23966   0.851562
# 6594            DraStic DS Emulator         GAME     4.6    87766  12.000000
# 6082                   Weather Live      WEATHER     4.5    76593   4.750000
# 7633        Five Nights at Freddy's         GAME     4.6   100805  50.000000
# 7954                    Bloons TD 5       FAMILY     4.6   190086  94.000000
# 7044                         Tasker        TOOLS     4.6    43045   3.400000
#
#       Installs  Type Price Content_Rating                     Genres  \
# 9220  10000000  Paid  6.99   Everyone 10+  Arcade;Action & Adventure
# 8825  10000000  Paid  0.99     Mature 17+                     Action
# 7151   1000000  Paid  6.99     Mature 17+                     Action
# 7477   1000000  Paid  5.99       Everyone                Photography
# 7977   1000000  Paid  5.99       Everyone                  Lifestyle
# 6594   1000000  Paid  4.99       Everyone                     Action
# 6082    500000  Paid  5.99       Everyone                    Weather
# 7633   1000000  Paid  2.99           Teen                     Action
# 7954   1000000  Paid  2.99       Everyone                   Strategy
# 7044   1000000  Paid  2.99       Everyone                      Tools
#
#      Revenue_Estimate
# 9220       69900000.0
# 8825        9900000.0
# 7151        6990000.0
# 7477        5990000.0
# 7977        5990000.0
# 6594        4990000.0
# 6082        2995000.0
# 7633        2990000.0
# 7954        2990000.0
# 7044        2990000.0

# %% [markdown]
# <h4 style="color:smokewhite;">Out of the top 10, how many are games?</h4>

# %%
top_10['Category'].value_counts()
# Out:
# Category
# GAME           4
# FAMILY         2
# PHOTOGRAPHY    1
# LIFESTYLE      1
# WEATHER        1
# TOOLS          1
# Name: count, dtype: int64

# %%
apps_below_250['Category'].nunique()
# Out:
# 33

# %%
top_10_categories = apps_below_250['Category'].value_counts().head(10)

# %%
bar = px.bar(x=top_10_categories.index, y=top_10_categories.values)
bar.show()

# %%
categories_installs = apps_below_250.groupby("Category").agg({"Installs":pd.Series.mean})

# %%
categories_installs.sort_values("Installs", ascending=True, inplace=True)

# %%
categories_installs
# Out:
#                          Installs
# Category
# MEDICAL              1.341188e+05
# EVENTS               3.544313e+05
# PARENTING            6.223222e+05
# BEAUTY               6.408619e+05
# AUTO_AND_VEHICLES    7.278055e+05
# LIBRARIES_AND_DEMO   8.137969e+05
# COMICS               8.320574e+05
# DATING               1.051585e+06
# FINANCE              1.538005e+06
# HOUSE_AND_HOME       1.565839e+06
# LIFESTYLE            1.695660e+06
# ART_AND_DESIGN       1.872674e+06
# FOOD_AND_DRINK       2.251891e+06
# BUSINESS             2.641291e+06
# FAMILY               2.763110e+06
# EDUCATION            2.990271e+06
# SPORTS               4.217044e+06
# MAPS_AND_NAVIGATION  4.264979e+06
# HEALTH_AND_FITNESS   4.666692e+06
# WEATHER              5.015229e+06
# PERSONALIZATION      5.142124e+06
# SHOPPING             7.779620e+06
# BOOKS_AND_REFERENCE  9.856755e+06
# TOOLS                1.126526e+07
# NEWS_AND_MAGAZINES   1.161329e+07
# GAME                 1.522941e+07
# TRAVEL_AND_LOCAL     1.548053e+07
# PHOTOGRAPHY          1.767735e+07
# PRODUCTIVITY         1.922947e+07
# ENTERTAINMENT        2.072216e+07
# VIDEO_PLAYERS        2.646552e+07
# SOCIAL               2.703370e+07
# COMMUNICATION        4.295425e+07

# %%
barh = px.bar(x=categories_installs.Installs, y=categories_installs.index, orientation='h')
barh.update_layout(xaxis_title="Number of Downloads", yaxis_title="Category")
barh.show()

# %%
cat_df = apps_below_250.groupby("Category").agg({"App":pd.Series.count, "Installs":pd.Series.mean})

# %%
cat_df
# Out:
#                       App      Installs
# Category
# ART_AND_DESIGN         61  1.872674e+06
# AUTO_AND_VEHICLES      73  7.278055e+05
# BEAUTY                 42  6.408619e+05
# BOOKS_AND_REFERENCE   169  9.856755e+06
# BUSINESS              262  2.641291e+06
# COMICS                 54  8.320574e+05
# COMMUNICATION         257  4.295425e+07
# DATING                134  1.051585e+06
# EDUCATION             118  2.990271e+06
# ENTERTAINMENT         102  2.072216e+07
# EVENTS                 45  3.544313e+05
# FAMILY               1606  2.763110e+06
# FINANCE               296  1.538005e+06
# FOOD_AND_DRINK         94  2.251891e+06
# GAME                  910  1.522941e+07
# HEALTH_AND_FITNESS    243  4.666692e+06
# HOUSE_AND_HOME         62  1.565839e+06
# LIBRARIES_AND_DEMO     64  8.137969e+05
# LIFESTYLE             297  1.695660e+06
# MAPS_AND_NAVIGATION   118  4.264979e+06
# MEDICAL               292  1.341188e+05
# NEWS_AND_MAGAZINES    204  1.161329e+07
# PARENTING              50  6.223222e+05
# PERSONALIZATION       298  5.142124e+06
# PHOTOGRAPHY           263  1.767735e+07
# PRODUCTIVITY          301  1.922947e+07
# SHOPPING              180  7.779620e+06
# SOCIAL                203  2.703370e+07
# SPORTS                260  4.217044e+06
# TOOLS                 719  1.126526e+07
# TRAVEL_AND_LOCAL      187  1.548053e+07
# VIDEO_PLAYERS         148  2.646552e+07
# WEATHER                72  5.015229e+06

# %%
cat_df.sort_values("App", ascending=False, inplace=True)
cat_df
# Out:
#                       App      Installs
# Category
# FAMILY               1606  2.763110e+06
# GAME                  910  1.522941e+07
# TOOLS                 719  1.126526e+07
# PRODUCTIVITY          301  1.922947e+07
# PERSONALIZATION       298  5.142124e+06
# LIFESTYLE             297  1.695660e+06
# FINANCE               296  1.538005e+06
# MEDICAL               292  1.341188e+05
# PHOTOGRAPHY           263  1.767735e+07
# BUSINESS              262  2.641291e+06
# SPORTS                260  4.217044e+06
# COMMUNICATION         257  4.295425e+07
# HEALTH_AND_FITNESS    243  4.666692e+06
# NEWS_AND_MAGAZINES    204  1.161329e+07
# SOCIAL                203  2.703370e+07
# TRAVEL_AND_LOCAL      187  1.548053e+07
# SHOPPING              180  7.779620e+06
# BOOKS_AND_REFERENCE   169  9.856755e+06
# VIDEO_PLAYERS         148  2.646552e+07
# DATING                134  1.051585e+06
# EDUCATION             118  2.990271e+06
# MAPS_AND_NAVIGATION   118  4.264979e+06
# ENTERTAINMENT         102  2.072216e+07
# FOOD_AND_DRINK         94  2.251891e+06
# AUTO_AND_VEHICLES      73  7.278055e+05
# WEATHER                72  5.015229e+06
# LIBRARIES_AND_DEMO     64  8.137969e+05
# HOUSE_AND_HOME         62  1.565839e+06
# ART_AND_DESIGN         61  1.872674e+06
# COMICS                 54  8.320574e+05
# PARENTING              50  6.223222e+05
# EVENTS                 45  3.544313e+05
# BEAUTY                 42  6.408619e+05

# %%
scat = px.scatter(data_frame=cat_df, x="App", y="Installs", title="Category Concentration", size="App", hover_name=cat_df.index, color="Installs")
scat.update_layout(xaxis_title="Number of Apps (lower=More concentrations)", yaxis_title="Installs", yaxis=dict(type="log"))
scat.show()

# %%
apps_below_250.head()
# Out:
#                                                 App Category  Rating  Reviews  \
# 21                              KBA-EZ Health Guide  MEDICAL     5.0        4
# 28                                         Ra Ga Ba     GAME     5.0        2
# 47                                          Mu.F.O.     GAME     5.0        2
# 82                                 Brick Breaker BR     GAME     5.0        7
# 99  Anatomy & Physiology Vocabulary Exam Review App  MEDICAL     5.0        1
#
#     Size_MBs  Installs  Type Price Content_Rating   Genres Revenue_Estimate
# 21      25.0         1  Free   0.0       Everyone  Medical              0.0
# 28      20.0         1  Paid  1.49       Everyone   Arcade             1.49
# 47      16.0         1  Paid  0.99       Everyone   Arcade             0.99
# 82      19.0         5  Free   0.0       Everyone   Arcade              0.0
# 99       4.6         5  Free   0.0       Everyone  Medical              0.0

# %%
apps_below_250["Genres"].nunique()
# Out:
# 114

# %%
apps_below_250['Genres'].value_counts()
# Out:
# Genres
# Tools                                718
# Entertainment                        467
# Education                            429
# Productivity                         301
# Personalization                      298
#                                     ...
# Adventure;Brain Games                  1
# Travel & Local;Action & Adventure      1
# Art & Design;Pretend Play              1
# Music & Audio;Music & Video            1
# Lifestyle;Pretend Play                 1
# Name: count, Length: 114, dtype: int64

# %%
stack = apps_below_250['Genres'].str.split(";", expand=True).stack()

# %%
stack
# Out:
# 21     0                    Medical
# 28     0                     Arcade
# 47     0                     Arcade
# 82     0                     Arcade
# 99     0                    Medical
#                      ...
# 10824  0               Productivity
# 10828  0    Video Players & Editors
# 10829  0    Video Players & Editors
# 10831  0           News & Magazines
# 10835  0                     Arcade
# Length: 8564, dtype: object

# %%
genres_stack = stack.value_counts()

# %%
bar = px.bar(x=genres_stack.index[:15], y=genres_stack.values[:15], title="Top Genres", hover_name=genres_stack.values[:15], color=genres_stack.values[:15], color_continuous_scale="Agsunset")
bar.update_layout(xaxis_title="Genres", yaxis_title="Number of Apps", coloraxis_showscale=False)
bar.show()

# %%
apps_below_250["Type"].value_counts()
# Out:
# Type
# Free    7595
# Paid     589
# Name: count, dtype: int64

# %%
df_free_vs_paid = apps_below_250.groupby(["Category", "Type"], as_index=False).agg({"App":pd.Series.count})

# %%
df_free_vs_paid
# Out:
#              Category  Type  App
# 0      ART_AND_DESIGN  Free   58
# 1      ART_AND_DESIGN  Paid    3
# 2   AUTO_AND_VEHICLES  Free   72
# 3   AUTO_AND_VEHICLES  Paid    1
# 4              BEAUTY  Free   42
# ..                ...   ...  ...
# 56   TRAVEL_AND_LOCAL  Paid    8
# 57      VIDEO_PLAYERS  Free  144
# 58      VIDEO_PLAYERS  Paid    4
# 59            WEATHER  Free   65
# 60            WEATHER  Paid    7
#
# [61 rows x 3 columns]

# %%
barg = px.bar(data_frame=df_free_vs_paid, x="Category", y="App", title="Free vs Paid App by Category", color="Type", barmode="group")
barg.update_layout(xaxis_title ="Category", yaxis_title = "Number of Apps", xaxis={"categoryorder":"total descending"}, yaxis=dict(type="log"))
barg.show()

# %%
box = px.box(apps_below_250, y="Installs", x="Type", color="Type", notched=True, points="all", title="How many downloads are paid apps giving up?")
box.update_layout(yaxis=dict(type='log'))
box.show()

# %%
df_paid_apps = apps_below_250[apps_below_250['Type'] == 'Paid']
box = px.box(df_paid_apps, 
             x='Category', 
             y='Revenue_Estimate',
             title='How Much Can Paid Apps Earn?')
 
box.update_layout(xaxis_title='Category',
                  yaxis_title='Paid App Ballpark Revenue',
                  xaxis={'categoryorder':'min ascending'},
                  yaxis=dict(type='log'))
 
 
box.show()

# %%
box = px.box(df_paid_apps,
             x='Category',
             y="Price",
             title='Price per Category')
 
box.update_layout(xaxis_title='Category',
                  yaxis_title='Paid App Price',
                  xaxis={'categoryorder':'max descending'},
                  yaxis=dict(type='log'))
 
box.show()
